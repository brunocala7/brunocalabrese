# %%
import pandas as pd
import seaborn as sns

df1 = pd.read_csv("turtles.csv",sep=",",encoding = "ISO-8859-1")
df2 = df1[["SEX","LENGTH","HEIGHT"]]
grafico = sns.pairplot(df2,hue="SEX",palette="coolwarm")

# %% [markdown]
# 1- El gráfico de arriba a la izquierda relaciona el sexo de las tortugas con el largo, mostrando que las tortugas femeninas son más largas que las masculinas.
# 2- En el gráfico de arriba a la derecha se visualizan todos los datos del dataframe. Se marcan puntos en las intersecciones del largo y la altura de cada dato, y con el color se marca el sexo.
# 3- Lo mismo que el gráfico 2, pero se invierten los ejes.
# 4- Parecido al gráfico 1, pero en este caso se relaciona el sexo con la altura.

# %% [markdown]
# 1er gráfico: se muestra que en general hubieron mas exportaciones, sobre todo en el 2018.
# 2do gráfico:

# %% [markdown]
# - Seleccionar un dataset
# - Seleccionar dos variables numéricas y una no numérica
# - Graficar la relación que existe entre las variables utilizando
# Seaborn.
# - Realizar una descripción de cada gráfico obtenido teniendo en cuenta la relación y
# comportamiento entre las variables seleccionadas.
# - El trabajo deberá ser entregado en un archivo .ipynb
